# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

import utils

# %% [markdown]
# #### Data Cleaning

# %%
dataset = pd.read_csv('data/train.csv', index_col='Id')
dataset = dataset.sample(frac=1).reset_index(drop=True)
data = dataset.head(1168)
crossval = dataset.tail(292)
numerical_data = data[utils.numerical_columns]

# %% [markdown]
# #### Feature Engineering

# %%
dataset.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          50       RL         48.0    12822   Pave   NaN      IR1
# 1          30       RL         85.0    10625   Pave   NaN      Reg
# 2          50       RL         51.0     4712   Pave   NaN      IR1
# 3          60       RL          NaN     9303   Pave   NaN      IR1
# 4          20       RL          NaN    10355   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
# 1         Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 2         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 4         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# #### Model Building

# %%
numerical_data.loc[:, numerical_data.columns != 'SalePrice'].columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFullBath',
#        'BsmtHalfBath', 'EnclosedPorch', 'Fireplaces', 'FullBath', 'GarageArea',
#        'GarageCars', 'GrLivArea', 'HalfBath', 'KitchenAbvGr', 'LotArea',
#        'LowQualFinSF', 'MiscVal', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PoolArea', 'ScreenPorch', 'TotalBsmtSF', 'TotRmsAbvGrd', 'WoodDeckSF',
#        'YearBuilt', 'YearRemodAdd'],
#       dtype='object')

# %%
y = numerical_data['SalePrice']
X = numerical_data.loc[:, numerical_data.columns != 'SalePrice'].values
X = sm.add_constant(X)

# %%
mod = sm.OLS(y, X)
res = mod.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     212.3
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):               0.00
# Time:                        20:05:26   Log-Likelihood:                -13834.
# No. Observations:                1168   AIC:                         2.772e+04
# Df Residuals:                    1141   BIC:                         2.786e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -1.02e+06   1.53e+05     -6.667      0.000   -1.32e+06    -7.2e+05
# ...

# %% [markdown]
# #### Cross Validation

# %%
coefs = res.coef()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-bebb9d6a7543> in <module>
# ----> 1 coefs = res.coef()
#
# ~/anaconda3/envs/kaggle/lib/python3.7/site-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'OLSResults' object has no attribute 'coef'
